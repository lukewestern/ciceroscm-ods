# %% [markdown]
# # CICERO SCM notebook example - interactive input

# %% [markdown]
# Import some stuff

# %%
import sys
import re
import os
import numpy as np
import shutil
import matplotlib.pyplot as plt
import pandas as pd
import pandas.testing as pdt
import warnings
import xarray as xr
try:
    from pandas.core.common import SettingWithCopyWarning
except:
    from pandas.errors import SettingWithCopyWarning
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)
sys.path.insert(0,os.path.join(os.getcwd(), '../', 'src'))
from ciceroscm import CICEROSCM
from ciceroscm.input_handler import read_inputfile,read_components,read_natural_emissions
# Out:
# /tmp/ipykernel_1977073/3555279312.py:7: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# Some functions to help with handling my own data

# %%
def to_df(cscm):
    """Convert the results of a CICEROSCM object to a DataFrame"""
    out=pd.concat([pd.DataFrame(v) for k, v in cscm.results.items()], axis = 1, keys = list(cscm.results.keys()))
    return out

def calc_beta(mol_mass):
    """Calculate the beta value for a given molecular mass"""
    return 1.7758620689655172e8 * mol_mass * 1e-9


def check_hfc(species):
    """Check if the species is an HFC and remove the hyphen"""
    if "HFC-" in species:
        sp_in = species.replace("-", "")
    else:
        sp_in = species
    return sp_in

def agage_emissions(species):
    """Read AGAGE emissions data for a given species"""
    py_path = f"/user/home/lw13938/work/py12box_agage/data/{species}/outputs/{species}_Global_annual_emissions.csv"
    em_csv = pd.read_csv(py_path, comment="#",index_col=False)
    index = em_csv['Decimal_date'].values.astype(int)
    data = em_csv['Global_annual_emissions'].values
    data[data < 0.] = 0.0
    sp_in = check_hfc(species)
    df = pd.DataFrame(index=index, data=data)
    df.index.name = "Component"
    df.columns = [sp_in]
    return df

def agage_mf(species):
    """Read AGAGE mole fractions data for a given species"""
    py_path = f"/user/home/lw13938/work/py12box_agage/data/{species}/outputs/{species}_Global_annual_mole_fraction.csv"
    mf_csv = pd.read_csv(py_path, comment="#",index_col=False)
    index = mf_csv['Decimal_date'].values.astype(int)
    data = mf_csv['Global_annual_mole_fraction'].values
    sp_in = check_hfc(species)
    df = pd.DataFrame(index=index, data=data)
    df.index.name = "Component"
    df.columns = [sp_in]
    return df

def zero_mf(species):
    """Create a DataFrame of zeros for a given species"""
    sp_in = check_hfc(species)
    dfc = pd.DataFrame(index=emi_input.index, columns=[sp_in], data=0)
    dfc.index.name = "Component"
    return dfc

test_data_dir = "/user/home/lw13938/work/ciceroscm/tests/test-data/"

# %% [markdown]
# Read in CICERO-SCM datafiles

# %%
# Read gas parameters
gaspam =read_components(test_data_dir + '/gases_v1RCMIP.txt')
df_nat_ch4 =read_natural_emissions(test_data_dir + '/natemis_ch4.txt','CH4')
df_nat_n2o =read_natural_emissions(test_data_dir + '/natemis_n2o.txt','N2O')
# Out:
# /user/work/lw13938/ciceroscm/src/ciceroscm/input_handler.py:39: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_gas = pd.read_csv(filename, delim_whitespace=True, index_col=0)

# %% [markdown]
# Add AGAGE data and add missing gases. \
# Gases are updated with the WMO 2022 lifetimes and SARFs.

# %%
# These are all the gases that are considered. Can add more if available or needed.
groups = {"all":[],
          "CFCs": ["CFC-11", "CFC-12", "CFC-113", "CFC-114", "CFC-115","CFC-13"],
          "HCFCs": ["HCFC-22", "HCFC-141b", "HCFC-142b", "HCFC-124", "HCFC-133a"],
          "HFCs": ["HFC-23", "HFC-32", "HFC-134a", "HFC-143a", "HFC-125",
                   "HFC-152a", "HFC-4310mee", "HFC-227ea", "HFC-365mfc",
                   "HFC-236fa", "HFC-245fa"], 
          "Solvents": ["CCl4", "CH3CCl3"],
          "PFCs":["CF4", "C2F6", "C3F8", "C4F8", "C4F10","C6F14"],
          "Other":["SF6", "NF3"],
          "Halons": ["H-1301", "H-2402", "H-1211"]}


df_rf = pd.read_csv("/user/home/lw13938/Python/bm_plots/Jens_RF_file/radiative_efficiency.updated.csv", comment="#")
rf_dict = {}
for gi, gas in enumerate(df_rf["Species"].values):
    rf_dict[gas] = df_rf["Recommended Adjusted Effective Radiative Efficiency (W/m2/ppX)"].values[gi]

sp_all = combined_list = [item for sublist in groups.values() for item in sublist]

# Add the extra species
df_si = pd.read_csv("work/py12box/py12box/data/inputs/species_info.csv", index_col=0)
for sp in sp_all:
    sp_in = check_hfc(sp)
    mol_mass = df_si.loc[sp]["Molecular mass (g/mol)"]  
    # lifetime = 1/(np.nanmax([1/df_si.loc[sp]["Lifetime stratosphere (years)"],0]) + \
    #             np.nanmax([1/df_si.loc[sp]["Lifetime other troposphere (years)"],0]) + \
    #             np.nanmax([1/df_si.loc[sp]["Lifetime ocean (years)"],0]))  
    lifetime = df_rf.loc[df_rf["Species"] == sp]["WMO (2022) Total Lifetime (years)"].values
    if sp not in gaspam.index and sp.replace("-","") not in gaspam.index:
        gaspam = pd.concat((gaspam, pd.DataFrame(index=[sp_in], data= {"EM_UNIT":"Gg", "CONC_UNIT":"ppt", "BETA":calc_beta(mol_mass), "ALPHA":rf_dict[sp]*1e-3, "TAU1":lifetime, "TAU2":0, "TAU3":0, "NAT_EM":0.0, "SARF_TO_ERF":1.0})))
    else:
        gaspam.loc[sp_in] = {"EM_UNIT":"Gg", "CONC_UNIT":"ppt", "BETA":calc_beta(mol_mass), "ALPHA":rf_dict[sp]*1e-3, "TAU1":lifetime, "TAU2":0, "TAU3":0, "NAT_EM":0.0, "SARF_TO_ERF":1.0}
        
# Add missing emissions and update with AGAGE numbers where available
df_ssp2_conc =read_inputfile(test_data_dir + '/ssp245_conc_RCMIP.txt')
emi_input =read_inputfile(test_data_dir + '/ssp245_em_RCMIP.txt')
emi_input.rename(columns={"CO2": "CO2_FF", "CO2.1": "CO2_AFOLU"}, inplace=True)
        
for sp in sp_all:
    if sp not in emi_input.columns and sp.replace("-","") not in emi_input.columns:
        df_sp = agage_emissions(sp).reindex(emi_input.index, fill_value=0)
        emi_input = pd.concat([emi_input, df_sp], axis=1)    
        # dfc_sp = zero_mf(sp).reindex(emi_input.index, fill_value=0)
        dfc_sp = agage_mf(sp).reindex(emi_input.index, fill_value=0)
        df_ssp2_conc = pd.concat([df_ssp2_conc, dfc_sp], axis=1)
    else:
        df_sp = agage_emissions(sp)
        sp_in = check_hfc(sp)
        emi_input[sp_in].update(df_sp[sp_in])
        df_sp = agage_mf(sp)
        df_ssp2_conc[sp_in].update(df_sp[sp_in])
df_ssp2_conc = df_ssp2_conc.fillna(0)
# Out:
# /user/work/lw13938/ciceroscm/src/ciceroscm/input_handler.py:98: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_input = pd.read_csv(
# /user/work/lw13938/ciceroscm/src/ciceroscm/input_handler.py:98: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_input = pd.read_csv(
# /tmp/ipykernel_1977073/2241979157.py:50: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   emi_input[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:52: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:50: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   emi_input[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:52: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:50: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   emi_input[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:52: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:50: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   emi_input[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:52: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:50: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   emi_input[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:52: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:50: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   emi_input[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:52: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:50: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   emi_input[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:52: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:50: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   emi_input[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:52: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:50: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   emi_input[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:52: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:50: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   emi_input[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:52: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:50: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   emi_input[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:52: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:50: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   emi_input[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:52: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:50: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   emi_input[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:52: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:50: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   emi_input[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:52: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:50: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   emi_input[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:52: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:50: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   emi_input[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:52: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:50: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   emi_input[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:52: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:50: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   emi_input[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:52: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:50: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   emi_input[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:52: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:50: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   emi_input[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:52: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:50: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   emi_input[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:52: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:50: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   emi_input[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:52: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:50: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   emi_input[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:52: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:50: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   emi_input[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:52: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:50: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   emi_input[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1977073/2241979157.py:52: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc[sp_in].update(df_sp[sp_in])

# %% [markdown]
# Run CICERO-SCM. In each loop, each 'group' of F-gases are zeroed and placed in to a dictionary.

# %%
def run_ciceroscm(gaspam_in, emi_input_in, df_ssp2_conc_in, conc_run=False):
    # NBVAL_IGNORE_OUTPUT
    scen = 'test'
    cscm_dir=CICEROSCM({
                "gaspam_data": gaspam_in,
                "emstart": 1750,  
                "conc_run":conc_run,
                "nystart": 1750,
                "nyend": 2024,
                "concentrations_data": df_ssp2_conc_in,
                "emissions_data": emi_input_in,
                "nat_ch4_data": df_nat_ch4,
                "nat_n2o_data": df_nat_n2o,
                "idtm":24,
            })

    # NBVAL_IGNORE_OUTPUT
    cscm_dir._run({
                "results_as_dict":True
            },
        pamset_udm={"threstemp": 7.0, #scales vertical velocity as a function of mixed layer temperature
                        "rlamdo":16.0,#air-sea heat exchange coefficient (wm^-2K^-1)
                        "akapa":0.634, #vertical heat diffusivity
                        "cpi":0.4, #temperature change ratio: polar to nonpolar region
                        "W":4, #vertical velocity (m/yr)
                        "beto":3.5, #ocean interhemispheric heat exchange coeff (Wm^-2K^-1)
                        "lambda":0.54,
                        "mixed":60.0,  #mixed layer depth
                        "foan":0.61, #fraction of northern hemisphere covered by ocean
                        "foas":0.81, #fraction of northern hemisphere covered by ocean
                        "ebbeta":0.0,#atmospheric interhemispheric heat exchange 
                        "fnso":0.7531, #ocean area ratio, northern to southern hemisphere
                        "lm":40, #number of vertical layers
                        "ldtime":12,
                    },
        pamset_emiconc={"lamb": 0.8,
                        "qbmb":0.03,
                        "qo3":0.4,
                        "qdirso2":-.457,
                        "qindso2":-.514,
                        "qbc":.2,
                        "qh2o_ch4":.171,
                        "qoc":-.103,
                        "ref_yr":2010,
                        "idtm":24})
    df_temp = to_df(cscm_dir)
    temp = np.squeeze(df_temp['dT_glob'].values)
    temp = temp[np.isfinite(temp)]
    frcing = df_temp['forcing']['Total_forcing'].values
    frcing = frcing[np.isfinite(frcing)]
    year = df_temp['concentrations'].Year.values
    year = year[np.isfinite(year)]
    return year, temp, frcing


df_dict = {}
df_rf_dict = {}

# for group in groups:
#     emi_input_in = emi_input.copy()
#     df_ssp2_conc_in = df_ssp2_conc.copy()
#     for species in groups[group]:
#         sp_in = check_hfc(species)
#         df_ssp2_conc_in[sp_in].values[:] = 0
#         emi_input_in[sp_in].values[:] = 0
#     year, temp, forcing = run_ciceroscm(gaspam, emi_input_in, df_ssp2_conc_in)
#     df_dict[group] = temp
#     df_rf_dict[group] = forcing
    
for group in groups:
    emi_input_in = emi_input.copy()
    df_ssp2_conc_in = df_ssp2_conc.copy()
    for sp in groups[group]:
        sp_in = check_hfc(sp)
        df_sp = zero_mf(sp).reindex(emi_input.index, fill_value=0)
        df_ssp2_conc_in[sp_in].update(df_sp[sp_in])
        df_ssp2_conc_in = df_ssp2_conc_in.fillna(0)
    year, temp, forcing = run_ciceroscm(gaspam, emi_input_in, df_ssp2_conc_in, conc_run=True)
    df_dict[group] = temp
    df_rf_dict[group] = forcing
# Out:
# /tmp/ipykernel_1799226/4103063589.py:76: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc_in[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1799226/4103063589.py:76: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc_in[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1799226/4103063589.py:76: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc_in[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1799226/4103063589.py:76: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc_in[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1799226/4103063589.py:76: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc_in[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1799226/4103063589.py:76: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc_in[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1799226/4103063589.py:76: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc_in[sp_in].update(df_sp[sp_in])

# %%
tpr = np.zeros(len(year))
rf = np.zeros(len(year))
temp0 = np.squeeze(df_dict["all"])
rf0 = np.squeeze(df_rf_dict["all"])
fig, ax = plt.subplots(1, 2, figsize=(12, 6))
for gr in list(df_dict.keys())[1:len(df_dict.keys())-1]:
    temp = temp0 - df_dict[gr]
    radfor = rf0 - df_rf_dict[gr]
    ax[0].fill_between(year, tpr, tpr+temp, label=gr, alpha=0.5)
    ax[1].fill_between(year, rf, rf+radfor, label=gr, alpha=0.5)
    tpr = tpr+temp
    rf = rf+radfor 
temp = temp0 - df_dict["Halons"]  
rf = rf0 - df_rf_dict["Halons"]   
ax[0].fill_between(year, np.zeros(len(year)), temp, label="Halons", alpha=0.5)
ax[1].fill_between(year, np.zeros(len(year)), rf, label="Halons", alpha=0.5)
ax[0].legend(loc="upper left", frameon=False)
ax[0].set_ylabel("Global mean temperature increase (K)")
ax[1].set_ylabel("Global radiative forcing (W m$^{-2}$)")
for axi in ax:
    axi.set_xlabel("Year")
    axi.set_xlim(1920,2025)

# %% [markdown]
# Compare to IPCC 2019 values

# %%
ipcc_erf_data = {
    "HFC134a": 0.018,
    "HFC23": 0.006,
    "HFC32": 0.002,
    "HFC125": 0.007,
    "HFC143a": 0.004,
    "SF6": 0.006,
    "CF4": 0.005,
    "C2F6": 0.001,
    "CFC-11": 0.066,
    "CFC-12": 0.180,
    "CFC-113": 0.021,
    "CFC-114": 0.005,
    "CFC-115": 0.002,
    "HCFC-22": 0.053,
    "HCFC-141b": 0.004,
    "HCFC-142b": 0.004,
    "CCl4": 0.013,
    "HFCs": 0.040,
    "PFCs": 0.007,
    "Halogenated species": 0.408,
    "CFCs+HCFCs+Other": 0.354,
}

# %%
for sp in list(ipcc_erf_data.keys())[:-4]:
    emi_input_in = emi_input.copy()
    df_ssp2_conc_in = df_ssp2_conc.copy()
    sp_in = check_hfc(sp)
    df_sp = zero_mf(sp).reindex(emi_input.index, fill_value=0)
    df_ssp2_conc_in[sp_in] = df_ssp2_conc_in[sp_in].update(df_sp[sp_in])
    df_ssp2_conc_in = df_ssp2_conc_in.fillna(0)
    year, temp, forcing = run_ciceroscm(gaspam, emi_input_in, df_ssp2_conc_in, conc_run=True)
    df_dict[sp_in] = temp
    df_rf_dict[sp_in] = forcing
# Out:
# /tmp/ipykernel_1799226/4206849594.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc_in[sp_in] = df_ssp2_conc_in[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1799226/4206849594.py:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_ssp2_conc_in = df_ssp2_conc_in.fillna(0)
# /tmp/ipykernel_1799226/4206849594.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc_in[sp_in] = df_ssp2_conc_in[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1799226/4206849594.py:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_ssp2_conc_in = df_ssp2_conc_in.fillna(0)
# /tmp/ipykernel_1799226/4206849594.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc_in[sp_in] = df_ssp2_conc_in[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1799226/4206849594.py:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_ssp2_conc_in = df_ssp2_conc_in.fillna(0)
# /tmp/ipykernel_1799226/4206849594.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc_in[sp_in] = df_ssp2_conc_in[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1799226/4206849594.py:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_ssp2_conc_in = df_ssp2_conc_in.fillna(0)
# /tmp/ipykernel_1799226/4206849594.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc_in[sp_in] = df_ssp2_conc_in[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1799226/4206849594.py:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_ssp2_conc_in = df_ssp2_conc_in.fillna(0)
# /tmp/ipykernel_1799226/4206849594.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc_in[sp_in] = df_ssp2_conc_in[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1799226/4206849594.py:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_ssp2_conc_in = df_ssp2_conc_in.fillna(0)
# /tmp/ipykernel_1799226/4206849594.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc_in[sp_in] = df_ssp2_conc_in[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1799226/4206849594.py:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_ssp2_conc_in = df_ssp2_conc_in.fillna(0)
# /tmp/ipykernel_1799226/4206849594.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc_in[sp_in] = df_ssp2_conc_in[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1799226/4206849594.py:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_ssp2_conc_in = df_ssp2_conc_in.fillna(0)
# /tmp/ipykernel_1799226/4206849594.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc_in[sp_in] = df_ssp2_conc_in[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1799226/4206849594.py:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_ssp2_conc_in = df_ssp2_conc_in.fillna(0)
# /tmp/ipykernel_1799226/4206849594.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc_in[sp_in] = df_ssp2_conc_in[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1799226/4206849594.py:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_ssp2_conc_in = df_ssp2_conc_in.fillna(0)
# /tmp/ipykernel_1799226/4206849594.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc_in[sp_in] = df_ssp2_conc_in[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1799226/4206849594.py:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_ssp2_conc_in = df_ssp2_conc_in.fillna(0)
# /tmp/ipykernel_1799226/4206849594.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc_in[sp_in] = df_ssp2_conc_in[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1799226/4206849594.py:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_ssp2_conc_in = df_ssp2_conc_in.fillna(0)
# /tmp/ipykernel_1799226/4206849594.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc_in[sp_in] = df_ssp2_conc_in[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1799226/4206849594.py:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_ssp2_conc_in = df_ssp2_conc_in.fillna(0)
# /tmp/ipykernel_1799226/4206849594.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc_in[sp_in] = df_ssp2_conc_in[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1799226/4206849594.py:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_ssp2_conc_in = df_ssp2_conc_in.fillna(0)
# /tmp/ipykernel_1799226/4206849594.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc_in[sp_in] = df_ssp2_conc_in[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1799226/4206849594.py:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_ssp2_conc_in = df_ssp2_conc_in.fillna(0)
# /tmp/ipykernel_1799226/4206849594.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc_in[sp_in] = df_ssp2_conc_in[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1799226/4206849594.py:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_ssp2_conc_in = df_ssp2_conc_in.fillna(0)
# /tmp/ipykernel_1799226/4206849594.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc_in[sp_in] = df_ssp2_conc_in[sp_in].update(df_sp[sp_in])
# /tmp/ipykernel_1799226/4206849594.py:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_ssp2_conc_in = df_ssp2_conc_in.fillna(0)

# %%
from adjustText import adjust_text
texts = []
for sp in list(ipcc_erf_data.keys())[:-2]:
    plt.plot(ipcc_erf_data[sp], rf0[year == 2019.]-df_rf_dict[sp][year == 2019.], "o")
    texts.append(plt.text(ipcc_erf_data[sp], rf0[year == 2019.]-df_rf_dict[sp][year == 2019.], sp, fontsize=8, transform=plt.gca().transData))
scmODSs = 0
# for group in ["CFCs","HCFCs","Solvents", "Halons"]:
for sp in list(ipcc_erf_data.keys())[:-2]:
    if "CFC" in sp or sp == "CCl4":
        scmODSs += rf0[year == 2019.]-df_rf_dict[sp][year == 2019.]
plt.plot(ipcc_erf_data["CFCs+HCFCs+Other"], scmODSs,"o")
texts.append(plt.text(ipcc_erf_data["CFCs+HCFCs+Other"], scmODSs, "ODSs", fontsize=8, transform=plt.gca().transData))
scmtot = 0
# for group in list(groups.keys())[1:]:
#     scmtot += rf0[year == 2019.]-df_rf_dict[group][year == 2019.]
for sp in list(ipcc_erf_data.keys())[:-4]:
    scmtot += rf0[year == 2019.]-df_rf_dict[sp][year == 2019.]
plt.plot(ipcc_erf_data["Halogenated species"], scmtot,"o")
texts.append(plt.text(ipcc_erf_data["Halogenated species"], scmtot, "Halogenated  gases", fontsize=8, transform=plt.gca().transData))
plt.yscale("log")
plt.xscale("log")
plt.xlabel("IPCC")
plt.ylabel("CICERO-SCM/AGAGE")
adjust_text(texts, only_move={'points':'y', 'texts':'y'}, arrowprops=dict(arrowstyle="->", color='k', lw=0.5))
plt.plot([1e-3,1],[1e-3,1], "k", linewidth=0.2)
plt.text(1e-3,1,"IPCC all halogenated gases = 0.408±0.078 Wm$^{-2}$", fontsize=8, transform=plt.gca().transData)
plt.text(1e-3,0.8,f"CICERO-SCM/AGAGE all halogenated gases = {np.round(scmtot[0],3)} Wm$^{'{-2}'}$", fontsize=8, transform=plt.gca().transData)

plt.text(1e-3,0.5,"IPCC ODSs = 0.354 Wm$^{-2}$", fontsize=8, transform=plt.gca().transData)
plt.text(1e-3,0.4,f"CICERO-SCM/AGAGE ODSs = {np.round(scmODSs[0],3)} Wm$^{'{-2}'}$", fontsize=8, transform=plt.gca().transData)
# Out:
# Text(0.001, 0.4, 'CICERO-SCM/AGAGE ODSs = 0.313 Wm$^{-2}$')

# %%
df_conc_rf_dict = {}
for group in groups:
    for si, sp in enumerate(groups[group]):
        sp_in = check_hfc(sp)
        forcing = df_ssp2_conc.loc[year.astype(int)][sp_in].values * gaspam.loc[sp_in]["ALPHA"]
        if si == 0:
            df_conc_rf_dict[group] = forcing
        else:
            df_conc_rf_dict[group] += forcing

# %%
df_conc_rf_dict["CFCs"]
# Out:
# array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        3.97129198e-07, 6.38777355e-06, 2.26492306e-05, 3.77493820e-05,
#        5.28493642e-05, 6.79493671e-05, 8.30493688e-05, 9.81493694e-05,
#        1.13249371e-04, 1.28489159e-04, 1.46355535e-04, 1.73719243e-04,
#        2.09118642e-04, 2.52522843e-04, 3.10865457e-04, 5.15582395e-04,
#        1.04098172e-03, 1.61020145e-03, 2.17967957e-03, 2.74995002e-03,
#        3.31354506e-03, 3.98236199e-03, 4.79675897e-03, 5.70060047e-03,
#        6.73392787e-03, 7.91089154e-03, 9.27806464e-03, 1.08514995e-02,
#        1.25136499e-02, 1.42250569e-02, 1.62042762e-02, 1.85691183e-02,
#        2.13260292e-02, 2.45931097e-02, 2.84423801e-02, 3.28578397e-02,
#        3.78035986e-02, 4.33507338e-02, 4.95976402e-02, 5.66395898e-02,
#        6.45054540e-02, 7.30692988e-02, 8.23906887e-02, 9.29692401e-02,
#        1.04542482e-01, 1.16352982e-01, 1.27799042e-01, 1.38978224e-01,
#        1.48933971e-01, 1.59062425e-01, 1.69242234e-01, 1.78493838e-01,
#        1.88697243e-01, 1.98528402e-01, 2.08505923e-01, 2.19477070e-01,
#        2.31344619e-01, 2.43911685e-01, 2.56977259e-01, 2.68638724e-01,
#        2.78498379e-01, 2.85970397e-01, 2.92047791e-01, 2.95958498e-01,
#        2.98816497e-01, 3.00970069e-01, 3.02800650e-01, 3.03740073e-01,
#        3.04177847e-01, 3.04351334e-01, 3.04676035e-01, 3.04413098e-01,
#        3.03695389e-01, 3.02901901e-01, 3.01919728e-01, 3.00867481e-01,
#        2.99398929e-01, 2.97834807e-01, 2.96258052e-01, 2.94602764e-01,
#        2.92957553e-01, 2.91173501e-01, 2.89432206e-01, 2.87773414e-01,
#        2.86248008e-01, 2.84455719e-01, 2.82505318e-01, 2.80930746e-01,
#        2.79478799e-01, 2.77508503e-01, 2.75318583e-01, 2.73069962e-01,
#        2.70959758e-01, 2.68660915e-01, 2.66436075e-01])

# %%
rf = np.zeros(len(year))
rfc = np.zeros(len(year))
rf0 = np.squeeze(df_rf_dict["all"])
fig, ax = plt.subplots(1, 2, figsize=(12, 6))
for gr in list(groups.keys())[1:len(groups.keys())-1]:
    radforc = df_conc_rf_dict[gr]
    radfor = rf0 - df_rf_dict[gr]
    ax[0].fill_between(year, rfc, rfc+radforc, label=gr, alpha=0.5)
    ax[1].fill_between(year, rf, rf+radfor, label=gr, alpha=0.5)
    rf = rf+radfor 
    rfc = rfc+radforc 
# rfc = rf0 - df_conc_rf_dict["Halons"]  
# rf = rf0 - df_rf_dict["Halons"]   
# ax[0].fill_between(year, np.zeros(len(year)), rfc, label="Halons", alpha=0.5)
# ax[1].fill_between(year, np.zeros(len(year)), rf, label="Halons", alpha=0.5)
ax[0].legend(loc="upper left", frameon=False)
ax[0].set_ylabel("Mole fraction derived radiative forcing (W m$^{-2}$)")
ax[1].set_ylabel("CICERO-SCM radiative forcing (W m$^{-2}$)")
for axi in ax:
    axi.set_xlabel("Year")
    axi.set_xlim(1920,2025)
    axi.set_ylim(0,0.42)

# %% [markdown]
# # Run an ensemble to explore the uncertainty

# %%
df_ssp2_conc0 = df_ssp2_conc.copy()
for sp in sp_all:
    sp_in = check_hfc(sp)
    df_sp = zero_mf(sp).reindex(emi_input.index, fill_value=0)
    df_ssp2_conc0[sp_in].update(df_sp[sp_in])
    df_ssp2_conc0 = df_ssp2_conc0.fillna(0)
year, temp0, forcing0 = run_ciceroscm(gaspam, emi_input, df_ssp2_conc0, conc_run=True)

csmsp = [check_hfc(item) for sublist in groups.values() for item in sublist]
nsamp = 500
temp_arr = np.zeros((len(year), nsamp)) 
forcing_arr = np.zeros((len(year), nsamp))
for i in range(nsamp):
    gaspam_in = gaspam.copy()
    for sp in csmsp:
        if gaspam_in.loc[sp,"TAU1"] < 5:
            gaspam_in.loc[sp,"ALPHA"] = np.random.normal(loc=gaspam_in.loc[sp,"ALPHA"], scale=0.26*gaspam_in.loc[sp,"ALPHA"])
        else:
            gaspam_in.loc[sp,"ALPHA"] = np.random.normal(loc=gaspam_in.loc[sp,"ALPHA"], scale=0.19*gaspam_in.loc[sp,"ALPHA"])
        if sp != "CFC-11" and sp != "CFC-12":
            gaspam_in.loc[sp,"SARF_TO_ERF"] = np.random.normal(loc=gaspam_in.loc[sp,"SARF_TO_ERF"], scale=0.13*gaspam_in.loc[sp,"SARF_TO_ERF"])
        
    year, temp, forcing = run_ciceroscm(gaspam_in, emi_input, df_ssp2_conc, conc_run=True)
    temp_arr[:,i] = temp - temp0
    forcing_arr[:,i] = forcing - forcing0
# Out:
# /tmp/ipykernel_1799226/2418901885.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ssp2_conc0[sp_in].update(df_sp[sp_in])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 23
#      20     if sp != "CFC-11" and sp != "CFC-12":
#      21         gaspam_in.loc[sp,"SARF_TO_ERF"] = np.random.normal(loc=gaspam_in.loc[sp,"SARF_TO_ERF"], scale=0.13*gaspam_in.loc[sp,"SARF_TO_ERF"])
# ---> 23 year, temp, forcing = run_ciceroscm(gaspam_in, emi_input, df_ssp2_conc, conc_run=True)
#      24 temp_arr[:,i] = temp - temp0
#      25 forcing_arr[:,i] = forcing - forcing0
#
# Cell In[6], line 18, in run_ciceroscm(gaspam_in, emi_input_in, df_ssp2_conc_in, conc_run)
#       4 cscm_dir=CICEROSCM({
#       5             "gaspam_data": gaspam_in,
#       6             "emstart": 1750,
#    (...)
#      14             "idtm":24,
#      15         })
#      17 # NBVAL_IGNORE_OUTPUT
# ---> 18 cscm_dir._run({
#      19             "results_as_dict":True
#      20         },
#      21     pamset_udm={"threstemp": 7.0, #scales vertical velocity as a function of mixed layer temperature
#      22                     "rlamdo":16.0,#air-sea heat exchange coefficient (wm^-2K^-1)
#      23                     "akapa":0.634, #vertical heat diffusivity
#      24                     "cpi":0.4, #temperature change ratio: polar to nonpolar region
#      25                     "W":4, #vertical velocity (m/yr)
#      26                     "beto":3.5, #ocean interhemispheric heat exchange coeff (Wm^-2K^-1)
#      27                     "lambda":0.54,
#      28                     "mixed":60.0,  #mixed layer depth
#      29                     "foan":0.61, #fraction of northern hemisphere covered by ocean
#      30                     "foas":0.81, #fraction of northern hemisphere covered by ocean
#      31                     "ebbeta":0.0,#atmospheric interhemispheric heat exchange
#      32                     "fnso":0.7531, #ocean area ratio, northern to southern hemisphere
#      33                     "lm":40, #number of vertical layers
#      34                     "ldtime":12,
#      35                 },
#      36     pamset_emiconc={"lamb": 0.8,
#      37                     "qbmb":0.03,
#      38                     "qo3":0.4,
#      39                     "qdirso2":-.457,
#      40                     "qindso2":-.514,
#      41                     "qbc":.2,
#      42                     "qh2o_ch4":.171,
#      43                     "qoc":-.103,
#      44                     "ref_yr":2010,
#      45                     "idtm":24})
#      46 df_temp = to_df(cscm_dir)
#      47 temp = np.squeeze(df_temp['dT_glob'].values)
#
# File /user/work/lw13938/ciceroscm/src/ciceroscm/ciceroscm.py:265, in CICEROSCM._run(self, cfg, pamset_udm, pamset_emiconc, make_plot)
#     263 for yr in range(self.cfg["nystart"], self.cfg["nyend"] + 1):
#     264     if not self.cfg["rf_run"]:
# --> 265         self.ce_handler.emi2conc(yr)
#     266         forc, fn, fs = self.ce_handler.conc2forc(
#     267             yr,
#     268             self.rf_luc.iloc[yr - self.cfg["nystart"], 0],
#     269             self.rf_volc_sun["sun"].iloc[yr - self.cfg["nystart"], 0],
#     270         )
#     272     else:
#
# File /user/work/lw13938/ciceroscm/src/ciceroscm/concentrations_emissions_handler.py:684, in ConcentrationsEmissionsHandler.emi2conc(self, yr)
#     674 # Do per tracer emissions to concentrations, update concentrations df
#     675 # NBNB! Remember to move calculation of  Trop_O3 concentration
#     676 # here from conc2forc.
#    (...)
#     681 #  + 0.0014 * (EMISSIONS(yr_ix,trcID("CO"))-EM2010(trcID("CO"))) &
#     682 #  + 0.0042 *(EMISSIONS(yr_ix,trcID("NMVOC"))-EM2010(trcID("NMVOC")))
#     683 if self.pamset["conc_run"]:
# --> 684     self.fill_one_row_conc(yr)
#     685     return
#     686 # Before emissions start
#
# File /user/work/lw13938/ciceroscm/src/ciceroscm/concentrations_emissions_handler.py:890, in ConcentrationsEmissionsHandler.fill_one_row_conc(self, yr, avoid)
#     888     continue
#     889 if tracer in self.conc_in:
# --> 890     value_dict[yr] = self.conc_in[tracer][yr]
#     891 else:
#     892     value_dict[yr] = 0
#
# File ~/.conda/envs/sklearn_env/lib/python3.12/site-packages/pandas/core/frame.py:4053, in DataFrame.__getitem__(self, key)
#    4051 check_dict_or_set_indexers(key)
#    4052 key = lib.item_from_zerodim(key)
# -> 4053 key = com.apply_if_callable(key, self)
#    4055 if is_hashable(key) and not is_iterator(key):
#    4056     # is_iterator to exclude generator e.g. test_getitem_listlike
#    4057     # shortcut if the key is in columns
#    4058     is_mi = isinstance(self.columns, MultiIndex)
#
# File ~/.conda/envs/sklearn_env/lib/python3.12/site-packages/pandas/core/common.py:370, in apply_if_callable(maybe_callable, obj, **kwargs)
#     363     # everything failed (probably because the argument
#     364     # wasn't actually callable); we return None
#     365     # instead of the empty string in this case to allow
#     366     # distinguishing between no name and a name of ''
#     367     return None
# --> 370 def apply_if_callable(maybe_callable, obj, **kwargs):
#     371     """
#     372     Evaluate possibly callable input using obj and kwargs if it is callable,
#     373     otherwise return as it is.
#    (...)
#     379     **kwargs
#     380     """
#     381     if callable(maybe_callable):
#
# KeyboardInterrupt:

# %%
fig, ax, = plt.subplots(1,2, figsize=(12,6))
ax[0].plot(year, temp_arr, linewidth=0.2, color="grey", alpha=0.3, zorder=0)
ax[0].plot(year, np.mean(temp_arr, axis=1))
ax[0].fill_between(year, np.percentile(temp_arr, 5, axis=1), np.percentile(temp_arr, 95, axis=1), alpha=0.6)
ax[0].set_ylabel("Global temperature increase (K)")
ax[0].set_xlabel("Year")
ax[0].set_xlim(1950,2025)
ax[0].set_ylim(0, None)
ax[1].plot(year, forcing_arr, linewidth=0.2, color="grey", alpha=0.3, zorder=0)
ax[1].plot(year, np.mean(forcing_arr, axis=1))
ax[1].fill_between(year, np.percentile(forcing_arr, 5, axis=1), np.percentile(forcing_arr, 95, axis=1), alpha=0.6)
ax[1].set_ylabel("Global radiative forcing (W m$^{-2}$)")
ax[1].set_xlabel("Year")
ax[1].set_xlim(1950,2025)
ax[1].set_ylim(0, None)
print(np.array([np.mean(forcing_arr, axis=1)[-1],np.percentile(forcing_arr, 5, axis=1)[-1], np.percentile(forcing_arr, 95, axis=1)[-1]]))
# Out:
# (0.0, 0.5183052623455169)
